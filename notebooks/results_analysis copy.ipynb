# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import json
from pathlib import Path

# %%
df = pd.read_csv('/home/hieule/research/reflector-position/results/experiments/memetic_hparam_sweep/sweep_summary.csv')

# %%
df.head()
# Out:
#                                           trial_name status  \
# 0                            baseline_current_config     ok
# 1  gd_lr_temp_alpha_001_learning_rate_0p01_softmi...     ok
# 2  gd_lr_temp_alpha_002_learning_rate_0p01_softmi...     ok
# 3  gd_lr_temp_alpha_003_learning_rate_0p01_softmi...     ok
# 4  gd_lr_temp_alpha_004_learning_rate_0p01_softmi...     ok
#
#    rank_by_best_primary_loss  ga_best_primary_loss  ga_best_softmin_loss  \
# 0                         15              0.388838                   NaN
# 1                         19              0.496736                   NaN
# 2                         17              0.388440                   NaN
# 3                         10              0.343256                   NaN
# 4                          7              0.295074                   NaN
#
#    ga_best_coverage_loss  ga_best_repulsion_loss  ga_best_mean_rssi  \
# 0                   -1.0                     NaN         -75.339088
# 1                   -1.0                     NaN         -75.377396
# 2                   -1.0                     NaN         -75.380379
# 3                   -1.0                     NaN         -75.317139
# 4                   -1.0                     NaN         -74.958817
#
#    ga_best_min_rssi  ga_best_p5_rssi  ...  total_duration_sec  \
# 0       -101.088058       -93.388931  ...          244.187491
# 1       -100.917191       -93.460320  ...          241.017704
# 2       -100.914246       -93.132973  ...          241.669024
# 3       -100.690735       -93.523140  ...          242.153583
# 4       -102.407471       -93.034889  ...          244.721433
#
#    runner_wall_clock_sec  num_ga_seeds  num_gd_tasks  num_gd_results  \
# 0             247.555681             5             5               5
# 1             244.408331             5             5               5
# 2             244.985241             5             5               5
# 3             245.423145             5             5               5
# 4             248.006353             5             5               5
#
#    best_primary_loss  best_primary_fitness  \
# 0           0.399050             -0.388838
# 1           0.510078             -0.496736
# 2           0.400638             -0.388440
# 3           0.347248             -0.343256
# 4           0.290681             -0.295074
#
#                                           output_dir  error  \
# 0  /home/hieule/research/reflector-position/resul...    NaN
# 1  /home/hieule/research/reflector-position/resul...    NaN
# 2  /home/hieule/research/reflector-position/resul...    NaN
# 3  /home/hieule/research/reflector-position/resul...    NaN
# 4  /home/hieule/research/reflector-position/resul...    NaN
#
#                                       overrides_json
# 0                                  {"verbose": true}
# 1  {"gd_optimization_params": {"learning_rate": 0...
# 2  {"gd_optimization_params": {"learning_rate": 0...
# 3  {"gd_optimization_params": {"learning_rate": 0...
# 4  {"gd_optimization_params": {"learning_rate": 0...
#
# [5 rows x 47 columns]

# %%
df
# Out:
#                                            trial_name status  \
# 0                             baseline_current_config     ok
# 1   gd_lr_temp_alpha_001_learning_rate_0p01_softmi...     ok
# 2   gd_lr_temp_alpha_002_learning_rate_0p01_softmi...     ok
# 3   gd_lr_temp_alpha_003_learning_rate_0p01_softmi...     ok
# 4   gd_lr_temp_alpha_004_learning_rate_0p01_softmi...     ok
# 5   gd_lr_temp_alpha_005_learning_rate_0p01_softmi...     ok
# 6   gd_lr_temp_alpha_006_learning_rate_0p01_softmi...     ok
# 7   gd_lr_temp_alpha_007_learning_rate_0p02_softmi...     ok
# 8   gd_lr_temp_alpha_008_learning_rate_0p02_softmi...     ok
# 9   gd_lr_temp_alpha_009_learning_rate_0p02_softmi...     ok
# 10  gd_lr_temp_alpha_010_learning_rate_0p02_softmi...     ok
# 11  gd_lr_temp_alpha_011_learning_rate_0p02_softmi...     ok
# 12  gd_lr_temp_alpha_012_learning_rate_0p02_softmi...     ok
# 13  gd_lr_temp_alpha_013_learning_rate_0p05_softmi...     ok
# 14  gd_lr_temp_alpha_014_learning_rate_0p05_softmi...     ok
# 15  gd_lr_temp_alpha_015_learning_rate_0p05_softmi...     ok
# 16  gd_lr_temp_alpha_016_learning_rate_0p05_softmi...     ok
# 17  gd_lr_temp_alpha_017_learning_rate_0p05_softmi...     ok
# 18  gd_lr_temp_alpha_018_learning_rate_0p05_softmi...     ok
# 19     ga_pop_mut_001_pop_size_100_n_gen_20_mutpb_0p7     ok
#
#     rank_by_best_primary_loss  ga_best_primary_loss  ga_best_softmin_loss  \
# 0                          15              0.388838                   NaN
# 1                          19              0.496736                   NaN
# 2                          17              0.388440                   NaN
# 3                          10              0.343256                   NaN
# 4                           7              0.295074                   NaN
# 5                           5              0.240763                   NaN
# 6                           2              0.216923                   NaN
# 7                          20              0.496671                   NaN
# 8                          16              0.390000                   NaN
# 9                          12              0.347892                   NaN
# 10                          9              0.297734                   NaN
# 11                          6              0.245431                   NaN
# 12                          3              0.218844                   NaN
# 13                         18              0.496681                   NaN
# 14                         14              0.388649                   NaN
# 15                         11              0.333868                   NaN
# 16                          8              0.296006                   NaN
# 17                          4              0.241399                   NaN
# 18                          1              0.204413                   NaN
# 19                         13              0.385505                   NaN
#
#     ga_best_coverage_loss  ga_best_repulsion_loss  ga_best_mean_rssi  \
# 0                    -1.0                     NaN         -75.339088
# 1                    -1.0                     NaN         -75.377396
# 2                    -1.0                     NaN         -75.380379
# 3                    -1.0                     NaN         -75.317139
# 4                    -1.0                     NaN         -74.958817
# 5                    -1.0                     NaN         -74.982635
# 6                    -1.0                     NaN         -74.534752
# 7                    -1.0                     NaN         -75.387413
# 8                    -1.0                     NaN         -75.265816
# 9                    -1.0                     NaN         -74.894531
# 10                   -1.0                     NaN         -74.932030
# 11                   -1.0                     NaN         -74.620834
# 12                   -1.0                     NaN         -74.385651
# 13                   -1.0                     NaN         -75.384964
# 14                   -1.0                     NaN         -75.354973
# 15                   -1.0                     NaN         -75.186607
# 16                   -1.0                     NaN         -74.873154
# 17                   -1.0                     NaN         -74.877068
# 18                   -1.0                     NaN         -74.517967
# 19                   -1.0                     NaN         -76.051949
#
#     ga_best_min_rssi  ga_best_p5_rssi  ...  total_duration_sec  \
# 0        -101.088058       -93.388931  ...          244.187491
# 1        -100.917191       -93.460320  ...          241.017704
# 2        -100.914246       -93.132973  ...          241.669024
# 3        -100.690735       -93.523140  ...          242.153583
# 4        -102.407471       -93.034889  ...          244.721433
# 5        -101.808472       -92.688911  ...          239.981140
# 6        -102.547592       -93.031303  ...          244.457394
# 7        -101.003235       -93.464600  ...          235.790299
# 8        -101.051239       -92.942856  ...          244.059677
# 9        -103.742538       -93.964737  ...          243.784264
# 10       -103.935593       -93.335770  ...          240.983716
# 11       -103.917801       -92.659081  ...          243.246621
# 12       -102.632751       -93.547829  ...          239.531724
# 13       -100.959656       -93.469658  ...          243.528867
# 14       -101.125443       -93.447121  ...          243.049967
# 15       -102.633942       -92.733337  ...          243.900058
# 16       -102.209839       -93.655182  ...          242.737810
# 17       -100.916992       -92.348190  ...          241.391975
# 18       -101.358917       -91.953087  ...          244.825077
# 19       -102.790970       -92.758820  ...          226.090809
#
#     runner_wall_clock_sec  num_ga_seeds  num_gd_tasks  num_gd_results  \
# 0              247.555681             5             5               5
# 1              244.408331             5             5               5
# 2              244.985241             5             5               5
# 3              245.423145             5             5               5
# 4              248.006353             5             5               5
# 5              243.311026             5             5               5
# 6              247.776917             5             5               5
# 7              239.301329             5             5               5
# 8              247.395113             5             5               5
# 9              247.111237             5             5               5
# 10             244.274746             5             5               5
# 11             246.528223             5             5               5
# 12             242.902659             5             5               5
# 13             247.058662             5             5               5
# 14             246.597128             5             5               5
# 15             247.180044             5             5               5
# 16             245.980472             5             5               5
# 17             244.534401             5             5               5
# 18             247.943510             5             5               5
# 19             229.343045             5             5               5
#
#     best_primary_loss  best_primary_fitness  \
# 0            0.399050             -0.388838
# 1            0.510078             -0.496736
# 2            0.400638             -0.388440
# 3            0.347248             -0.343256
# 4            0.290681             -0.295074
# 5            0.240806             -0.240763
# 6            0.218438             -0.216923
# 7            0.516328             -0.496671
# 8            0.399149             -0.390000
# 9            0.353220             -0.347892
# 10           0.300058             -0.297734
# 11           0.246113             -0.245431
# 12           0.220061             -0.218844
# 13           0.497285             -0.496681
# 14           0.390685             -0.388649
# 15           0.348676             -0.333868
# 16           0.291537             -0.296006
# 17           0.239800             -0.241399
# 18           0.207183             -0.204413
# 19           0.385720             -0.385505
#
#                                            output_dir  error  \
# 0   /home/hieule/research/reflector-position/resul...    NaN
# 1   /home/hieule/research/reflector-position/resul...    NaN
# 2   /home/hieule/research/reflector-position/resul...    NaN
# 3   /home/hieule/research/reflector-position/resul...    NaN
# 4   /home/hieule/research/reflector-position/resul...    NaN
# 5   /home/hieule/research/reflector-position/resul...    NaN
# 6   /home/hieule/research/reflector-position/resul...    NaN
# 7   /home/hieule/research/reflector-position/resul...    NaN
# 8   /home/hieule/research/reflector-position/resul...    NaN
# 9   /home/hieule/research/reflector-position/resul...    NaN
# 10  /home/hieule/research/reflector-position/resul...    NaN
# 11  /home/hieule/research/reflector-position/resul...    NaN
# 12  /home/hieule/research/reflector-position/resul...    NaN
# 13  /home/hieule/research/reflector-position/resul...    NaN
# 14  /home/hieule/research/reflector-position/resul...    NaN
# 15  /home/hieule/research/reflector-position/resul...    NaN
# 16  /home/hieule/research/reflector-position/resul...    NaN
# 17  /home/hieule/research/reflector-position/resul...    NaN
# 18  /home/hieule/research/reflector-position/resul...    NaN
# 19  /home/hieule/research/reflector-position/resul...    NaN
#
#                                        overrides_json
# 0                                   {"verbose": true}
# 1   {"gd_optimization_params": {"learning_rate": 0...
# 2   {"gd_optimization_params": {"learning_rate": 0...
# 3   {"gd_optimization_params": {"learning_rate": 0...
# 4   {"gd_optimization_params": {"learning_rate": 0...
# 5   {"gd_optimization_params": {"learning_rate": 0...
# 6   {"gd_optimization_params": {"learning_rate": 0...
# 7   {"gd_optimization_params": {"learning_rate": 0...
# 8   {"gd_optimization_params": {"learning_rate": 0...
# 9   {"gd_optimization_params": {"learning_rate": 0...
# 10  {"gd_optimization_params": {"learning_rate": 0...
# 11  {"gd_optimization_params": {"learning_rate": 0...
# 12  {"gd_optimization_params": {"learning_rate": 0...
# 13  {"gd_optimization_params": {"learning_rate": 0...
# 14  {"gd_optimization_params": {"learning_rate": 0...
# 15  {"gd_optimization_params": {"learning_rate": 0...
# 16  {"gd_optimization_params": {"learning_rate": 0...
# 17  {"gd_optimization_params": {"learning_rate": 0...
# 18  {"gd_optimization_params": {"learning_rate": 0...
# 19  {"ga_params": {"mutpb": 0.7, "n_gen": 20, "pop...
#
# [20 rows x 47 columns]

# %%
# ── Load trend CSVs (one per trial) ──────────────────────────────────────────
SWEEP_DIR = Path('/home/hieule/research/reflector-position/results/experiments/memetic_hparam_sweep')
TRENDS_DIR = SWEEP_DIR / 'trends'

gd_histories = {}    # trial_name -> DataFrame
ga_generations = {}  # trial_name -> DataFrame

if TRENDS_DIR.exists():
    for p in sorted(TRENDS_DIR.glob('*_gd_history.csv')):
        trial = p.stem.replace('_gd_history', '')
        gd_histories[trial] = pd.read_csv(p)
    for p in sorted(TRENDS_DIR.glob('*_ga_generations.csv')):
        trial = p.stem.replace('_ga_generations', '')
        ga_generations[trial] = pd.read_csv(p)

print(f"GD trend files loaded : {len(gd_histories)}")
print(f"GA trend files loaded : {len(ga_generations)}")
# Out:
# GD trend files loaded : 20
# GA trend files loaded : 20

# %%
# ── Summary / ranking table ───────────────────────────────────────────────────
RANK_COLS = [
    'trial_name',
    'ga_best_primary_loss',
    'gd_initial_primary_loss', 'gd_best_primary_loss', 'gd_final_primary_loss',
    'ga_best_mean_rssi', 'ga_best_min_rssi', 'ga_best_p5_rssi', 'ga_best_coverage_pct',
    'gd_best_mean_rssi',  'gd_best_min_rssi',  'gd_best_p5_rssi',  'gd_best_coverage_pct',
    'gd_final_mean_rssi', 'gd_final_min_rssi', 'gd_final_p5_rssi', 'gd_final_coverage_pct',
    'total_time_s',
]

available = [c for c in RANK_COLS if c in df.columns]
df_rank = df[available].sort_values('gd_best_primary_loss', ascending=True).reset_index(drop=True)
df_rank.index += 1  # 1-based rank

# Highlight numeric columns with gradients
float_cols = df_rank.select_dtypes(include='number').columns.tolist()
styler = df_rank.style

# Lower loss is better
if 'gd_best_primary_loss' in df_rank.columns:
    styler = styler.background_gradient(subset=['gd_best_primary_loss'], cmap='RdYlGn_r')

# RSSI gradients by postfix group so GA/GD are directly comparable per metric
rssi_postfixes = ['mean_rssi', 'min_rssi', 'p5_rssi']
for postfix in rssi_postfixes:
    cols = [c for c in df_rank.columns if c.endswith(postfix)]
    if cols:
        vals = df_rank[cols].to_numpy(dtype=float)
        vmin = np.nanmin(vals)
        vmax = np.nanmax(vals)
        styler = styler.background_gradient(
            subset=cols, cmap='RdYlGn', axis=None, vmin=vmin, vmax=vmax
        )

styler \
    .format({c: '{:.4f}' for c in float_cols}) \
    .set_caption('Trials ranked by GD best primary loss (lower = better)')
# Out:
# <style type="text/css">
# #T_bccc8_row0_col3, #T_bccc8_row0_col7, #T_bccc8_row9_col6, #T_bccc8_row11_col13 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bccc8_row0_col5, #T_bccc8_row14_col9 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_bccc8_row0_col6, #T_bccc8_row2_col3 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_bccc8_row0_col9, #T_bccc8_row9_col10, #T_bccc8_row18_col10 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_bccc8_row0_col10, #T_bccc8_row8_col13, #T_bccc8_row14_col10 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_bccc8_row0_col11 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_bccc8_row0_col13, #T_bccc8_row3_col3, #T_bccc8_row4_col3, #T_bccc8_row7_col9 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_bccc8_row0_col14 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_bccc8_row0_col15, #T_bccc8_row16_col15 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_bccc8_row1_col3 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_bccc8_row1_col5, #T_bccc8_row15_col9, #T_bccc8_row17_col7, #T_bccc8_row18_col7, #T_bccc8_row19_col7 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_bccc8_row1_col6, #T_bccc8_row2_col13 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_bccc8_row1_col7, #T_bccc8_row6_col7 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_bccc8_row1_col9, #T_bccc8_row13_col10 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_bccc8_row1_col10, #T_bccc8_row7_col11, #T_bccc8_row10_col7, #T_bccc8_row10_col10 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_bccc8_row1_col11 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_bccc8_row1_col13, #T_bccc8_row3_col7, #T_bccc8_row19_col10 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_bccc8_row1_col14 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_bccc8_row1_col15, #T_bccc8_row2_col7, #T_bccc8_row5_col14 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_bccc8_row2_col5 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_bccc8_row2_col6, #T_bccc8_row10_col6 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_bccc8_row2_col9, #T_bccc8_row15_col6, #T_bccc8_row16_col10 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_bccc8_row2_col10, #T_bccc8_row5_col6, #T_bccc8_row8_col6 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_bccc8_row2_col11, #T_bccc8_row4_col14 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_bccc8_row2_col14, #T_bccc8_row11_col15, #T_bccc8_row12_col5, #T_bccc8_row19_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bccc8_row2_col15 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_bccc8_row3_col5, #T_bccc8_row7_col5 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_bccc8_row3_col6, #T_bccc8_row16_col6, #T_bccc8_row18_col6 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_bccc8_row3_col9, #T_bccc8_row15_col10 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_bccc8_row3_col10 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_bccc8_row3_col11, #T_bccc8_row19_col13 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_bccc8_row3_col13, #T_bccc8_row8_col15, #T_bccc8_row12_col7, #T_bccc8_row17_col14 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_bccc8_row3_col14 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_bccc8_row3_col15, #T_bccc8_row8_col11, #T_bccc8_row9_col9 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_bccc8_row4_col5, #T_bccc8_row18_col11 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_bccc8_row4_col6, #T_bccc8_row17_col10 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_bccc8_row4_col7, #T_bccc8_row19_col14 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_bccc8_row4_col9, #T_bccc8_row13_col11 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_bccc8_row4_col10 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_bccc8_row4_col11 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_bccc8_row4_col13, #T_bccc8_row13_col9, #T_bccc8_row16_col7 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_bccc8_row4_col15 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_bccc8_row5_col3, #T_bccc8_row12_col6 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_bccc8_row5_col5 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_bccc8_row5_col7 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_bccc8_row5_col9 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_bccc8_row5_col10, #T_bccc8_row14_col14 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_bccc8_row5_col11 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_bccc8_row5_col13, #T_bccc8_row6_col6 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_bccc8_row5_col15, #T_bccc8_row10_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_bccc8_row6_col3, #T_bccc8_row7_col3, #T_bccc8_row8_col14, #T_bccc8_row10_col14 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_bccc8_row6_col5 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_bccc8_row6_col9 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_bccc8_row6_col10 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_bccc8_row6_col11 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_bccc8_row6_col13, #T_bccc8_row15_col7 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_bccc8_row6_col14 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_bccc8_row6_col15 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_bccc8_row7_col6 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_bccc8_row7_col7 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_bccc8_row7_col10 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_bccc8_row7_col13 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_bccc8_row7_col14 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_bccc8_row7_col15, #T_bccc8_row9_col11 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_bccc8_row8_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_bccc8_row8_col5 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_bccc8_row8_col7 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_bccc8_row8_col9 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_bccc8_row8_col10 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_bccc8_row9_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_bccc8_row9_col5 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_bccc8_row9_col7, #T_bccc8_row16_col13 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_bccc8_row9_col13 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_bccc8_row9_col14 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_bccc8_row9_col15 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_bccc8_row10_col5 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_bccc8_row10_col9, #T_bccc8_row15_col11, #T_bccc8_row19_col11 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_bccc8_row10_col11, #T_bccc8_row13_col14 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_bccc8_row10_col13 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_bccc8_row10_col15, #T_bccc8_row11_col9 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_bccc8_row11_col3 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_bccc8_row11_col5 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_bccc8_row11_col6 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_bccc8_row11_col7 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_bccc8_row11_col10 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_bccc8_row11_col11, #T_bccc8_row16_col11 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_bccc8_row11_col14, #T_bccc8_row12_col9, #T_bccc8_row12_col13 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_bccc8_row12_col3 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_bccc8_row12_col10, #T_bccc8_row12_col11, #T_bccc8_row12_col14, #T_bccc8_row12_col15, #T_bccc8_row16_col14 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_bccc8_row13_col3, #T_bccc8_row14_col15 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_bccc8_row13_col5 {
#   background-color: #fca

# %%
# ── GA vs GD comparison — best-checkpoint physical metrics (Top 5 by GD mean RSSI) ──
METRIC_PAIRS = [
    ('ga_best_mean_rssi',     'gd_best_mean_rssi',     'Mean RSSI (dBm)'),
    ('ga_best_min_rssi',      'gd_best_min_rssi',      'Min RSSI (dBm)'),
    ('ga_best_p5_rssi',       'gd_best_p5_rssi',       '5th-pct RSSI (dBm)'),
    ('ga_best_coverage_pct',  'gd_best_coverage_pct',  'Coverage (%)'),
]

if 'gd_best_mean_rssi' not in df.columns:
    print("Column 'gd_best_mean_rssi' not found in CSV.")
else:
    df_plot = df.sort_values('gd_best_mean_rssi', ascending=False).head(5).reset_index(drop=True)
    df_plot['rank'] = np.arange(1, len(df_plot) + 1)

    rank_cols = [c for c in ['rank', 'trial_name', 'gd_best_mean_rssi', 'ga_best_mean_rssi'] if c in df_plot.columns]
    display(df_plot[rank_cols])

    valid_pairs = [(a, b, label) for a, b, label in METRIC_PAIRS
                   if a in df_plot.columns and b in df_plot.columns]

    if valid_pairs and len(df_plot) > 0:
        n_metrics = len(valid_pairs)
        fig, axes = plt.subplots(1, n_metrics, figsize=(5 * n_metrics, 5))
        if n_metrics == 1:
            axes = [axes]

        x = np.arange(len(df_plot))
        width = 0.38

        for ax, (ga_col, gd_col, label) in zip(axes, valid_pairs):
            ax.bar(x - width / 2, df_plot[ga_col], width, label='GA best', color='steelblue', alpha=0.85)
            ax.bar(x + width / 2, df_plot[gd_col], width, label='GD best', color='tomato',    alpha=0.85)
            ax.set_xlabel('Top-5 run rank')
            ax.set_ylabel(label)
            ax.set_title(label)
            ax.set_xticks(x)
            if 'trial_name' in df_plot.columns:
                ax.set_xticklabels(
                    [f"#{r} {t}" for r, t in zip(df_plot['rank'], df_plot['trial_name'])],
                    rotation=45, ha='right', fontsize=7
                )
            else:
                ax.set_xticklabels([f"#{r}" for r in df_plot['rank']], rotation=0)
            ax.legend()
            ax.grid(axis='y', linestyle='--', alpha=0.5)

        fig.suptitle('GA vs GD — Top 5 runs ranked by GD best mean RSSI', fontsize=13, y=1.02)
        plt.tight_layout()
        plt.show()
    else:
        print("No GA/GD metric columns available for top-5 plotting.")
# Out:
#    rank                                         trial_name  gd_best_mean_rssi  \
# 0     1  gd_lr_temp_alpha_012_learning_rate_0p02_softmi...         -73.722504
# 1     2  gd_lr_temp_alpha_018_learning_rate_0p05_softmi...         -73.801140
# 2     3  gd_lr_temp_alpha_006_learning_rate_0p01_softmi...         -73.838272
# 3     4  gd_lr_temp_alpha_016_learning_rate_0p05_softmi...         -73.921616
# 4     5  gd_lr_temp_alpha_011_learning_rate_0p02_softmi...         -73.930496
#
#    ga_best_mean_rssi
# 0         -74.385651
# 1         -74.517967
# 2         -74.534752
# 3         -74.873154
# 4         -74.620834

# %%
# ── GD iteration history — Top 5 runs by GD best mean RSSI ────────────────────
if 'gd_best_mean_rssi' not in df.columns:
    print("Column 'gd_best_mean_rssi' not found in CSV.")
else:
    df_top5 = df.sort_values('gd_best_mean_rssi', ascending=False).head(5)
    if 'trial_name' in df_top5.columns:
        top5_trials = df_top5['trial_name'].astype(str).tolist()
        gd_histories_top5 = {t: gd_histories[t] for t in top5_trials if t in gd_histories}
    else:
        gd_histories_top5 = {}

    if gd_histories_top5:
        GD_TREND_METRICS = [
            ('primary_loss',  'GD Primary Loss'),
            ('mean_rssi',     'Mean RSSI (dBm)'),
            ('min_rssi',      'Min RSSI (dBm)'),
            ('p5_rssi',       '5th-pct RSSI (dBm)'),
            ('coverage_pct',  'Coverage (%)'),
        ]

        n_plots = len(GD_TREND_METRICS)
        fig, axes = plt.subplots(1, n_plots, figsize=(5 * n_plots, 4))
        colors = cm.tab20(np.linspace(0, 1, len(gd_histories_top5)))

        for ax, (col, ylabel) in zip(axes, GD_TREND_METRICS):
            for (trial, hist), color in zip(gd_histories_top5.items(), colors):
                if col in hist.columns:
                    ax.plot(hist['step'], hist[col], label=trial, color=color, linewidth=1.2, alpha=0.85)
            ax.set_xlabel('GD iteration')
            ax.set_ylabel(ylabel)
            ax.set_title(ylabel)
            ax.grid(linestyle='--', alpha=0.4)

        handles, labels = axes[0].get_legend_handles_labels()
        fig.legend(handles, labels, loc='lower center', ncol=min(4, len(gd_histories_top5)),
                   bbox_to_anchor=(0.5, -0.18), fontsize=8)
        fig.suptitle('GD optimisation — Top 5 runs by GD best mean RSSI', fontsize=13)
        plt.tight_layout()
        plt.show()
    else:
        print("No GD history trend files found for top-5 ranked runs in", TRENDS_DIR)

# %%
# ── GA generation history — Top 5 runs by GD best mean RSSI ───────────────────
if 'gd_best_mean_rssi' not in df.columns:
    print("Column 'gd_best_mean_rssi' not found in CSV.")
else:
    df_top5 = df.sort_values('gd_best_mean_rssi', ascending=False).head(5)
    if 'trial_name' in df_top5.columns:
        top5_trials = df_top5['trial_name'].astype(str).tolist()
        ga_generations_top5 = {t: ga_generations[t] for t in top5_trials if t in ga_generations}
    else:
        ga_generations_top5 = {}

    if ga_generations_top5:
        GA_TREND_METRICS = [
            ('best_primary_loss',   'GA Best Primary Loss'),
            ('mean_primary_fitness','GA Mean Fitness'),
            ('std',                 'Fitness Std Dev'),
        ]

        n_plots = len(GA_TREND_METRICS)
        fig, axes = plt.subplots(1, n_plots, figsize=(5 * n_plots, 4))
        colors = cm.tab20(np.linspace(0, 1, len(ga_generations_top5)))

        for ax, (col, ylabel) in zip(axes, GA_TREND_METRICS):
            for (trial, hist), color in zip(ga_generations_top5.items(), colors):
                if col in hist.columns:
                    ax.plot(hist['gen'], hist[col], label=trial, color=color, linewidth=1.2, alpha=0.85)
            ax.set_xlabel('Generation')
            ax.set_ylabel(ylabel)
            ax.set_title(ylabel)
            ax.grid(linestyle='--', alpha=0.4)

        handles, labels = axes[0].get_legend_handles_labels()
        fig.legend(handles, labels, loc='lower center', ncol=min(4, len(ga_generations_top5)),
                   bbox_to_anchor=(0.5, -0.18), fontsize=8)
        fig.suptitle('GA evolution — Top 5 runs by GD best mean RSSI', fontsize=13)
        plt.tight_layout()
        plt.show()
    else:
        print("No GA generation trend files found for top-5 ranked runs in", TRENDS_DIR)

# %%
# ── Best trial deep-dive: GA best + GD initial → best → final ────────────────
if 'gd_best_mean_rssi' in df.columns and len(df) > 0:
    best_row = df.loc[(df['gd_best_mean_rssi']-df["ga_best_mean_rssi"]).idxmax()]
    best_name = best_row.get('trial_name', str((df['gd_best_mean_rssi']-df["ga_best_mean_rssi"]).idxmax()))
    print(f"Best trial: {best_name}")

    CHECKPOINT_GROUPS = {
        'GA best':   {'prefix': 'ga_best_'},
        'GD initial':{'prefix': 'gd_initial_'},
        'GD best':   {'prefix': 'gd_best_'},
        'GD final':  {'prefix': 'gd_final_'},
    }
    FIELDS = ['primary_loss', 'softmin_loss', 'coverage_loss', 'repulsion_loss',
              'mean_rssi', 'min_rssi', 'p5_rssi', 'coverage_pct']

    records = []
    for label, cfg in CHECKPOINT_GROUPS.items():
        row = {'checkpoint': label}
        for f in FIELDS:
            col = cfg['prefix'] + f
            row[f] = best_row.get(col, np.nan)
        records.append(row)

    df_deep = pd.DataFrame(records).set_index('checkpoint')

    # Styled table
    float_c = df_deep.select_dtypes('number').columns.tolist()
    display_df = df_deep.style \
        .background_gradient(subset=['primary_loss'], cmap='RdYlGn_r') \
        .background_gradient(subset=[c for c in float_c if 'rssi' in c], cmap='RdYlGn') \
        .format({c: '{:.4f}' for c in float_c}) \
        .set_caption(f'Best trial: {best_name} — all checkpoint metrics')
    display(display_df)

    # Bar chart for RSSI metrics across checkpoints
    rssi_cols = ['mean_rssi', 'min_rssi', 'p5_rssi']
    rssi_data = df_deep[rssi_cols].dropna(how='all')
    if not rssi_data.empty:
        x = np.arange(len(rssi_data))
        width = 0.25
        fig, ax = plt.subplots(figsize=(8, 4))
        for i, col in enumerate(rssi_cols):
            ax.bar(x + i * width, rssi_data[col], width, label=col.replace('_', ' ').title())
        ax.set_xticks(x + width)
        ax.set_xticklabels(rssi_data.index)
        ax.set_ylabel('RSSI (dBm)')
        ax.set_title(f'Best trial: RSSI metrics across checkpoints\n({best_name})')
        ax.legend()
        ax.grid(axis='y', linestyle='--', alpha=0.5)
        plt.tight_layout()
        plt.show()
else:
    print("Run the sweep and reload to see best-trial deep-dive.")
# Out:
# Best trial: gd_lr_temp_alpha_014_learning_rate_0p05_softmin_temperature_0p05_alpha_0p99
# <style type="text/css">
# #T_2529d_row0_col0, #T_2529d_row0_col5, #T_2529d_row2_col6, #T_2529d_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2529d_row0_col4, #T_2529d_row3_col0, #T_2529d_row3_col5, #T_2529d_row3_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2529d_row0_col6 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_2529d_row1_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_2529d_row1_col4 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_2529d_row1_col5 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_2529d_row1_col6 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_2529d_row2_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_2529d_row2_col4 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_2529d_row2_col5 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2529d">
#   <caption>Best trial: gd_lr_temp_alpha_014_learning_rate_0p05_softmin_temperature_0p05_alpha_0p99 — all checkpoint metrics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2529d_level0_col0" class="col_heading level0 col0" >primary_loss</th>
#       <th id="T_2529d_level0_col1" class="col_heading level0 col1" >softmin_loss</th>
#       <th id="T_2529d_level0_col2" class="col_heading level0 col2" >coverage_loss</th>
#       <th id="T_2529d_level0_col3" class="col_heading level0 col3" >repulsion_loss</th>
#       <th id="T_2529d_level0_col4" class="col_heading level0 col4" >mean_rssi</th>
#       <th id="T_2529d_level0_col5" class="col_heading level0 col5" >min_rssi</th>
#       <th id="T_2529d_level0_col6" class="col_heading level0 col6" >p5_rssi</th>
#       <th id="T_2529d_level0_col7" class="col_heading level0 col7" >coverage_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >checkpoint</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2529d_level0_row0" class="row_heading level0 row0" >GA best</th>
#       <td id="T_2529d_row0_col0" class="data row0 col0" >0.3886</td>
#       <td id="T_2529d_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_2529d_row0_col2" class="data row0 col2" >-1.0000</td>
#       <td id="T_2529d_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_2529d_row0_col4" class="data row0 col4" >-75.3550</td>
#       <td id="T_2529d_row0_col5" class="data row0 col5" >-101.1254</td>
#       <td id="T_2529d_row0_col6" class="data row0 col6" >-93.4471</td>
#       <td id="T_2529d_row0_col7" class="data row0 col7" >100.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2529d_level0_row1" class="row_heading level0 row1" >GD initial</th>
#       <td id="T_2529d_row1_col0" class="data row1 col0" >0.4078</td>
#       <td id="T_2529d_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_2529d_row1_col2" class="data row1 col2" >-1.0000</td>
#       <td id="T_2529d_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_2529d_row1_col4" class="data row1 col4" >-75.2320</td>
#       <td id="T_2529d_row1_col5" class="data row1 col5" >-102.5152</td>
#       <td id="T_2529d_row1_col6" class="data row1 col6" >-94.1380</td>
#       <td id="T_2529d_row1_col7" class="data row1 col7" >100.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2529d_level0_row2" class="row_heading level0 row2" >GD best</th>
#       <td id="T_2529d_row2_col0" class="data row2 col0" >0.3907</td>
#       <td id="T_2529d_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_2529d_row2_col2" class="data row2 col2" >-1.0000</td>
#       <td id="T_2529d_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_2529d_row2_col4" class="data row2 col4" >-74.3393</td>
#       <td id="T_2529d_row2_col5" class="data row2 col5" >-101.8923</td>
#       <td id="T_2529d_row2_col6" class="data row2 col6" >-93.0893</td>
#       <td id="T_2529d_row2_col7" class="data row2 col7" >100.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2529d_level0_row3" class="row_heading level0 row3" >GD final</th>
#       <td id="T_2529d_row3_col0" class="data row3 col0" >0.4255</td>
#       <td id="T_2529d_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_2529d_row3_col2" class="data row3 col2" >-1.0000</td>
#       <td id="T_2529d_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_2529d_row3_col4" class="data row3 col4" >-74.2491</td>
#       <td id="T_2529d_row3_col5" class="data row3 col5" >-106.5084</td>
#       <td id="T_2529d_row3_col6" class="data row3 col6" >-94.2212</td>
#       <td id="T_2529d_row3_col7" class="data row3 col7" >100.0000</td>
#     </tr>
#   </tbody>
# </table>
